# %% [markdown]
# # Mathematische Modelle zur Beschreibung von Daten

# %% [markdown]
# Anhand des Datensatzes (https://datahub.io/core/global-temp#data) wollen wir zwei grundsätzlich verschiedene Vorhersagen miteinander vergleichen:
#
# K-Neighbors-Regression
#
# Lineare-Regression

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import scipy, scipy.stats
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_json("../data/monthly_json.json") 
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#         Date    Mean   Source
# 0 2016-12-06  0.7895     GCAG
# 1 2016-12-06  0.8100  GISTEMP
# 2 2016-11-06  0.7504     GCAG
# 3 2016-11-06  0.9300  GISTEMP
# 4 2016-10-06  0.7292     GCAG

# %% [markdown]
# Zunächst will ich die Daten etwas umformatieren, so dass das Datum zum index des Dataframes wird und die verschiedenen Quellen (Source) als Spalten dargestellt werden. Dazu nutze ich die Pivot-Funktion von pandas:

# %%
pivot_df = data.pivot(index='Date', columns='Source', values='Mean')

# %%
pivot_df.head()
# Out:
# Source        GCAG  GISTEMP
# Date
# 1880-01-06  0.0009    -0.30
# 1880-02-06 -0.1229    -0.21
# 1880-03-06 -0.1357    -0.18
# 1880-04-06 -0.0499    -0.27
# 1880-05-06 -0.0738    -0.14

# %% [markdown]
# Wie ich aus der Beschreibung der Daten weiß, handelt es sich um einen zeitlichen Verlauf der Temperaturmittelwerte. Diesen will ich zunächst einmal visualisieren um ein gefühl dafür zu bekommen.

# %%
GCAG_data = pivot_df['GCAG'].plot(figsize=(20, 8))

# %%
GCAG_data = pivot_df['GCAG']

X = GCAG_data.index.values.astype(np.int64) / 1000000000 
X = X.reshape(-1, 1)
X
# Out:
# array([[-2.8397088e+09],
#        [-2.8370304e+09],
#        [-2.8345248e+09],
#        ...,
#        [ 1.4757120e+09],
#        [ 1.4783904e+09],
#        [ 1.4809824e+09]])

# %%
y = pivot_df['GCAG'].values

# %% [markdown]
# ---

# %%
y = y.reshape(-1,1)

# %% [markdown]
# Aufgabe:
# - Implementiere Logistische Regression
# - Teile die Daten in ein Train- und Test-set
# - Berechne Trainings- und Test- Fehler für KNR und Lineare Regression

# %%
err = []
nat = range(2,30)
for i in nat:
    neigh = KNeighborsRegressor(n_neighbors=i, algorithm='brute', weights='uniform' )
    neigh.fit(X, y)
    y_predicted = neigh.predict(X)

    #plt.figure(figsize=(20,8))
    #plt.plot(X,X_predicted)
    #plt.show()
    

    #Fehler:
    err.append((sum((y_predicted - y)**2))/len(y))
plt.figure(figsize=(20,8))
plt.plot(nat, err);

# %%
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X, y)
y_predicted = neigh.predict(X)

# %%
plt.figure(figsize=(20,8))
plt.plot(X,y_predicted)
plt.show()

# %% [markdown]
# Unterteilung in Trainings und Testdaten

# %%
pivot_df['time'] = X

# %%
pivot_df
# Out:
# Source        GCAG  GISTEMP          time
# Date
# 1880-01-06  0.0009    -0.30 -2.839709e+09
# 1880-02-06 -0.1229    -0.21 -2.837030e+09
# 1880-03-06 -0.1357    -0.18 -2.834525e+09
# 1880-04-06 -0.0499    -0.27 -2.831846e+09
# 1880-05-06 -0.0738    -0.14 -2.829254e+09
# 1880-06-06 -0.1692    -0.29 -2.826576e+09
# 1880-07-06 -0.1491    -0.24 -2.823984e+09
# 1880-08-06 -0.0725    -0.08 -2.821306e+09
# 1880-09-06 -0.0817    -0.17 -2.818627e+09
# 1880-10-06 -0.1786    -0.16 -2.816035e+09
# 1880-11-06 -0.2672    -0.19 -2.813357e+09
# 1880-12-06 -0.0775    -0.22 -2.810765e+09
# 1881-01-06 -0.0205    -0.10 -2.808086e+09
# 1881-02-06 -0.0296    -0.14 -2.805408e+09
# 1881-03-06  0.0348     0.01 -2.802989e+09
# 1881-04-06  0.0734    -0.03 -2.800310e+09
# 1881-05-06  0.0284    -0.04 -2.797718e+09
# 1881-06-06 -0.0892    -0.28 -2.795040e+09
# 1881-07-06 -0.0329    -0.07 -2.792448e+09
# 1881-08-06 -0.0519    -0.03 -2.789770e+09
# 1881-09-06 -0.1824    -0.09 -2.787091e+09
# 1881-10-06 -0.2207    -0.20 -2.784499e+09
# 1881-11-06 -0.2194    -0.26 -2.781821e+09
# 1881-12-06 -0.0439    -0.16 -2.779229e+09
# 1882-01-06  0.0883     0.09 -2.776550e+09
# 1882-02-06  0.0385     0.08 -2.773872e+09
# 1882-03-06  0.0754     0.01 -2.771453e+09
# 1882-04-06 -0.1241    -0.20 -2.768774e+09
# 1882-05-06 -0.1459    -0.18 -2.766182e+09
# 1882-06-06 -0.1391    -0.25 -2.763504e+09
# ...            ...      ...           ...
# 2014-07-06  0.6988     0.57  1.404605e+09
# 2014-08-06  0.7986     0.82  1.407283e+09
# 2014-09-06  0.7872     0.90  1.409962e+09
# 2014-10-06  0.7851     0.85  1.412554e+09
# 2014-11-06  0.6895     0.67  1.415232e+09
# 2014-12-06  0.8308     0.79  1.417824e+09
# 2015-01-06  0.8141     0.81  1.420502e+09
# 2015-02-06  0.8843     0.86  1.423181e+09
# 2015-03-06  0.8969     0.90  1.425600e+09
# 2015-04-06  0.7741     0.74  1.428278e+09
# 2015-05-06  0.8584     0.78  1.430870e+09
# 2015-06-06  0.8835     0.78  1.433549e+09
# 2015-07-06  0.8072     0.71  1.436141e+09
# 2015-08-06  0.8746     0.78  1.438819e+09
# 2015-09-06  0.9260     0.81  1.441498e+09
# 2015-10-06  0.9913     1.06  1.444090e+09
# 2015-11-06  0.9655     1.04  1.446768e+09
# 2015-12-06  1.1219     1.11  1.449360e+09
# 2016-01-06  1.0569     1.17  1.452038e+09
# 2016-02-06  1.1921     1.35  1.454717e+09
# 2016-03-06  1.2245     1.30  1.457222e+09
# 2016-04-06  1.0733     1.09  1.459901e+09
# 2016-05-06  0.8738     0.93  1.462493e+09
# 2016-06-06  0.9006     0.76  1.465171e+09
# 2016-07-06  0.8687     0.83  1.467763e+09
# 2016-08-06  0.8998     0.98  1.470442e+09
# 2016-09-06  0.8767     0.87  1.473120e+09
# 2016-10-06  0.7292     0.89  1.475712e+09
# 2016-11-06  0.7504     0.93  1.478390e+09
# 2016-12-06  0.7895     0.81  1.480982e+09
#
# [1644 rows x 3 columns]

# %% [markdown]
# Lineare Regression

# %%
from sklearn import linear_model as lr # importieren der Klasse
lr = lr.LinearRegression()                             # instanziieren der Klasse
lr.fit(X, y)

y_lr_predicted = lr.predict(X)


plt.plot(X,y_lr_predicted)

# %%
results_lr = pd.DataFrame(X)
results_lr['Vorhersage'] = y_lr_predicted
results_lr['y'] = y
RSS_lr = ((sum((y_predicted - y)**2))/len(y))

# %%
print(RSS_lr)
# Out:
# [0.00301561]

# %%
err[0]
# Out:
# array([0.00301203])

# %%
plt.figure(figsize=(20,8))
plt.plot(X,y_predicted)
plt.plot(X, y_lr_predicted)
plt.show()
print(lr.coef_, lr.intercept_)
# Out:
# [[2.16128702e-10]] [0.19564161]

# %%
lr.predict(0)
# Out:
# array([[0.19564161]])

# %%
lr.predict(1) - lr.predict(0)
# Out:
# array([[2.16128698e-10]])

# %% [markdown]
# # f(x) = 2.16128702e-10*x + 0.19564161

# %%
type(X)
# Out:
# numpy.ndarray

# %%
y = y.reshape(-1,1)

# %%
y.shape
# Out:
# (1644, 1)

# %%
np.
