# %%
Pseudocode: 
definiere Klasse Auto
    mit Eigenschaften:
        Hersteller String
        Typ String
        Ladekapazität float
        PS int
        Max_personen int
        Station(Standort)
        vermietet (Boolean) default False

        Definiere Klasse Stationen als Liste:
    mit Eigenschaften:
        Name
        Strasse
        PLZ
        Ort

Funktion: addCar (H,T,L,P,M,S)
    erzeuge Instanz der Klasse Auto mit den Parametern
    addiere diese Instanz zur Variablen fuhrpark

Funktion: addStation(N,S,P,O)
    Erzeuge Instanz der Klasse Stationen mit den Parameter
    addiere diese zur Liste Stationsliste
    

Def Variable Stationsliste:
    Variable Fuhrpark

    addStation
    addStation
    
    addCar
    *4
    
    Fuhrpark:
        H    T   L   PS  M   S   V
    0   Fiat Duca100 50  3   0   False
    1   VW   Golf 200150 5   1   False
    ...
    3   ...
    
    

    alle Autos anzeigen: fuhrpark -> Auto1, Auto2, Auto3, Auto4
    alle vermieteten Autos: Fuhrpark where vermietet=True = Summe von Fuhrpark[,5]=True
        
        Besser mit Labels:
            vergebe Labels für die erste Zeile von Fuhrpark
    alle vermieteten Autos: Fuhrpark where vermietet=True = Summe von Fuhrpark[,vermietet]=True   
    Anzahl aller Auto: len(fuhrpark)
    Anzahl aller Autos einer Station: Summe Fuhrpark S where Station = 0
